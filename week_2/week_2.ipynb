# %% [markdown]
# This notebook runs the functions which are used to process the data and train the BERT-Tiny model with a hyperparameter sweep.

# %% [markdown]
# # Definitions and dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/WandB/week_2

import sys
sys.path.append('./')
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install -r requirements.txt
# !pip install kaggle

# !mkdir /root/.kaggle

# !mv ../../../../kaggle.json /root/.kaggle/kaggle.json

# !chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# # Process and Train Data

# %%
# !python process.py

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !python train.py

# %%
# %env WANDB_LOG_MODEL=true
# !wandb sweep sweep.yaml

# %%
# !wandb agent dmeltzer/mlops-course-assgn2/dqin7gdg --count 20
# Out:
# Streaming output truncated to the last 5000 lines.
#  76% 829/1096 [00:11<00:04, 65.31it/s]
#  76% 836/1096 [00:11<00:03, 65.59it/s]
#  77% 843/1096 [00:11<00:03, 65.06it/s]
#  78% 850/1096 [00:11<00:03, 64.00it/s]
#  78% 857/1096 [00:11<00:03, 64.47it/s]
#  79% 864/1096 [00:11<00:03, 64.83it/s]
#  79% 871/1096 [00:11<00:03, 64.63it/s]
#  80% 878/1096 [00:11<00:03, 62.20it/s]
#  81% 885/1096 [00:12<00:03, 63.27it/s]
#  81% 892/1096 [00:12<00:03, 64.60it/s]
#  82% 899/1096 [00:12<00:03, 65.00it/s]
#  83% 906/1096 [00:12<00:02, 64.34it/s]
#  83% 913/1096 [00:12<00:02, 64.51it/s]
#  84% 920/1096 [00:12<00:02, 64.63it/s]
#  85% 927/1096 [00:12<00:02, 65.66it/s]
#  85% 934/1096 [00:12<00:02, 65.03it/s]
#  86% 941/1096 [00:12<00:02, 63.49it/s]
#  86% 948/1096 [00:13<00:02, 64.47it/s]
#  87% 955/1096 [00:13<00:02, 65.44it/s]
#  88% 962/1096 [00:13<00:02, 62.48it/s]
#  88% 969/1096 [00:13<00:01, 63.83it/s]
#  89% 976/1096 [00:13<00:01, 64.91it/s]
#  90% 983/1096 [00:13<00:01, 62.97it/s]
# ...
